# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristoRay/ChrisPortofolioForDS/blob/main/Fifa_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/content/data_awal.csv')
df.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#Drop unecessary column that we'll definitely not use
df.drop(columns = ['ID','Photo','Flag', 'Club Logo', 'Real Face', 'Contract Valid Until'], inplace = True)
df.head()
# Out:
#    Unnamed: 0               Name  ...  GKReflexes Release Clause
# 0           0           L. Messi  ...         8.0        €226.5M
# 1           1  Cristiano Ronaldo  ...        11.0        €127.1M
# 2           2          Neymar Jr  ...        11.0        €228.1M
# 3           3             De Gea  ...        94.0        €138.6M
# 4           4       K. De Bruyne  ...        13.0        €196.4M
#
# [5 rows x 83 columns]

# %%
#check the results
df.info()
'''
we can inferr that, some columns are better of in float/integer dtype and data 
frame needs to be separated between outfield player and GK
'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 83 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     18207 non-null  object
#  8   Wage                      18207 non-null  object
#  9   Special                   18207 non-null  int64
#  10  Preferred Foot            18159 non-null  object
#  11  International Reputation  18159 non-null  float64
#  12  Weak Foot                 18159 non-null  float64
# ...

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
#since some players doesn't have postion, we drop these players
df.dropna(subset=['Position'], inplace = True)
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
df_outfield = df[df['Position']!='GK'].copy()
df_GK = df[df['Position']=='GK'].copy()

# %%
df_outfield.head()
# Out:
#    Unnamed: 0               Name  ...  GKReflexes Release Clause
# 0           0           L. Messi  ...         8.0        €226.5M
# 1           1  Cristiano Ronaldo  ...        11.0        €127.1M
# 2           2          Neymar Jr  ...        11.0        €228.1M
# 4           4       K. De Bruyne  ...        13.0        €196.4M
# 5           5          E. Hazard  ...         8.0        €172.1M
#
# [5 rows x 83 columns]

# %%
df_GK.head()
# Out:
#     Unnamed: 0           Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 3            3         De Gea   27  ...          88.0        94.0         €138.6M
# 9            9       J. Oblak   25  ...          88.0        89.0         €144.5M
# 18          18  M. ter Stegen   26  ...          85.0        90.0         €123.3M
# 19          19    T. Courtois   26  ...          86.0        88.0         €113.7M
# 22          22       M. Neuer   32  ...          87.0        87.0          €62.7M
#
# [5 rows x 83 columns]

# %% [markdown]
# ## Preprocessing on Outfield DF

# %%
df_outfield.head()
# Out:
#    Unnamed: 0               Name  ...  GKReflexes Release Clause
# 0           0           L. Messi  ...         8.0        €226.5M
# 1           1  Cristiano Ronaldo  ...        11.0        €127.1M
# 2           2          Neymar Jr  ...        11.0        €228.1M
# 4           4       K. De Bruyne  ...        13.0        €196.4M
# 5           5          E. Hazard  ...         8.0        €172.1M
#
# [5 rows x 83 columns]

# %%
df_outfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16122 entries, 0 to 18206
# Data columns (total 83 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                16122 non-null  int64
#  1   Name                      16122 non-null  object
#  2   Age                       16122 non-null  int64
#  3   Nationality               16122 non-null  object
#  4   Overall                   16122 non-null  int64
#  5   Potential                 16122 non-null  int64
#  6   Club                      15926 non-null  object
#  7   Value                     16122 non-null  object
#  8   Wage                      16122 non-null  object
#  9   Special                   16122 non-null  int64
#  10  Preferred Foot            16122 non-null  object
#  11  International Reputation  16122 non-null  float64
#  12  Weak Foot                 16122 non-null  float64
# ...

# %%
df_outfield.isnull().sum().sort_values(ascending = False)
# Out:
# Loaned From       14947
# Release Clause     1379
# Joined             1371
# Club                196
# Name                  0
#                   ...
# LongPassing           0
# BallControl           0
# Acceleration          0
# SprintSpeed           0
# Unnamed: 0            0
# Length: 83, dtype: int64

# %%
df_outfield.drop(columns= ['Loaned From'], inplace = True)

#check for missing values in each column
df_outfield.isnull().sum().sort_values(ascending = False)
# Out:
# Release Clause    1379
# Joined            1371
# Club               196
# CAM                  0
# RS                   0
#                   ...
# LongPassing          0
# BallControl          0
# Acceleration         0
# SprintSpeed          0
# Unnamed: 0           0
# Length: 82, dtype: int64

# %%
df_outfield.columns
'''
for now, let's rename one of the columns to id, later if we don't need them,
we can just delete
'''
df_outfield.rename(columns = {'Unnamed: 0':'id'}, inplace = True)

# %%
df_outfield.head()
# Out:
#    id               Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 0   0           L. Messi   31  ...          14.0         8.0         €226.5M
# 1   1  Cristiano Ronaldo   33  ...          14.0        11.0         €127.1M
# 2   2          Neymar Jr   26  ...          15.0        11.0         €228.1M
# 4   4       K. De Bruyne   27  ...          10.0        13.0         €196.4M
# 5   5          E. Hazard   27  ...           8.0         8.0         €172.1M
#
# [5 rows x 82 columns]

# %%
df_outfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16122 entries, 0 to 18206
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16122 non-null  int64
#  1   Name                      16122 non-null  object
#  2   Age                       16122 non-null  int64
#  3   Nationality               16122 non-null  object
#  4   Overall                   16122 non-null  int64
#  5   Potential                 16122 non-null  int64
#  6   Club                      15926 non-null  object
#  7   Value                     16122 non-null  object
#  8   Wage                      16122 non-null  object
#  9   Special                   16122 non-null  int64
#  10  Preferred Foot            16122 non-null  object
#  11  International Reputation  16122 non-null  float64
#  12  Weak Foot                 16122 non-null  float64
# ...

# %%
'''since it's outfield player dataframe, we will not need any GK stats. so let's 
drop them and also, since we subset this dataframe from the original, might 
aswell reset the index'''
df_outfield.drop(columns =['id','GKHandling','GKDiving','GKKicking','GKPositioning','GKReflexes']
                 ,inplace = True)
df_outfield.reset_index(drop = True, inplace = True)
df_outfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 76 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16122 non-null  object
#  1   Age                       16122 non-null  int64
#  2   Nationality               16122 non-null  object
#  3   Overall                   16122 non-null  int64
#  4   Potential                 16122 non-null  int64
#  5   Club                      15926 non-null  object
#  6   Value                     16122 non-null  object
#  7   Wage                      16122 non-null  object
#  8   Special                   16122 non-null  int64
#  9   Preferred Foot            16122 non-null  object
#  10  International Reputation  16122 non-null  float64
#  11  Weak Foot                 16122 non-null  float64
#  12  Skill Moves               16122 non-null  float64
# ...

# %%
#check the height and weight column, and see how we'll tackle this column
df_outfield[['Height','Weight']].head()
# Out:
#   Height  Weight
# 0    5'7  159lbs
# 1    6'2  183lbs
# 2    5'9  150lbs
# 3   5'11  154lbs
# 4    5'8  163lbs

# %%
#to change it to cm, we can use split like this
df_outfield['Height'].str.split("'")[0]
# Out:
# ['5', '7']

# %%
'''now, since the height column is not in the right datatype, we'll change it to 
cm using a function'''
def ConvertHeight(x):
  #The column values should look something like this 5'7
   ht_ = x.split("'")
   ft_ = round(float((ht_[0])),2) * 12 * 2.54
   in_ = round(float((ht_[1])),2) * 2.54
   return (ft_ + in_)

df_outfield['Height'] = df_outfield['Height'].apply(lambda x : ConvertHeight(x))
df_outfield['Height'].head()
# Out:
# 0    170.18
# 1    187.96
# 2    175.26
# 3    180.34
# 4    172.72
# Name: Height, dtype: float64

# %%
#now on to the next one
print(df_outfield['Weight'].head())
# Out:
# 0    159lbs
# 1    183lbs
# 2    150lbs
# 3    154lbs
# 4    163lbs
# Name: Weight, dtype: object

# %%
#check whether each column ends with lbs
df_outfield['Weight'].str.contains('lbs').sum()
#since this is the case, then we'll use string manipulation
# Out:
# 16122

# %%
#let's convert it to Kg
df_outfield['Weight'] = df_outfield['Weight'].str[:-3].astype(float)
df_outfield['Weight'] = round(df_outfield['Weight'] * 0.453592,2)
df_outfield['Weight'].head()
# Out:
# 0    72.12
# 1    83.01
# 2    68.04
# 3    69.85
# 4    73.94
# Name: Weight, dtype: float64

# %%
df_outfield.info()
#looks like both weight and height column are already in the correct dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 76 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16122 non-null  object
#  1   Age                       16122 non-null  int64
#  2   Nationality               16122 non-null  object
#  3   Overall                   16122 non-null  int64
#  4   Potential                 16122 non-null  int64
#  5   Club                      15926 non-null  object
#  6   Value                     16122 non-null  object
#  7   Wage                      16122 non-null  object
#  8   Special                   16122 non-null  int64
#  9   Preferred Foot            16122 non-null  object
#  10  International Reputation  16122 non-null  float64
#  11  Weak Foot                 16122 non-null  float64
#  12  Skill Moves               16122 non-null  float64
# ...

# %%
#another columns that needs to change are Values, Wage and Release Clause
df_outfield[['Value','Wage','Release Clause']].head()
# Out:
#      Value   Wage Release Clause
# 0  €110.5M  €565K        €226.5M
# 1     €77M  €405K        €127.1M
# 2  €118.5M  €290K        €228.1M
# 3    €102M  €355K        €196.4M
# 4     €93M  €340K        €172.1M

# %%
'''
since for value column ends with either M or K, we need to check if it's
consistent all the way 
'''
nominals = df_outfield['Value'].str[-1]
nominals.value_counts()
# Out:
# K    9558
# M    6360
# 0     204
# Name: Value, dtype: int64

# %%
#looks like that column ends with either M K or 0
df_outfield['Value'].str.contains('M|K|0').sum()
# Out:
# 16122

# %%
df_outfield[df_outfield['Value'].str[-1]=='0']
'''
players with value ends with 0 means they have no value
'''
# Out:
# '\nplayers with value ends with 0 means they have no value\n'

# %%
'''
just like before, we'll make a function to convert it and apply it to each 
column
'''
def EuroConvert(x):
  # format : Eurosign .... K/M/0
  l = len(x)
  end = x[-1]
  if end == 'M' :
    value = float (x[1:l-1]) * 1000000
  elif end == 'K' :
    value = value = float (x[1:l-1]) * 1000
  else :
    value = 0
  return value

df_outfield['Value'] = df_outfield['Value'].apply(lambda x: EuroConvert(x))

# %%
df_outfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 76 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16122 non-null  object
#  1   Age                       16122 non-null  int64
#  2   Nationality               16122 non-null  object
#  3   Overall                   16122 non-null  int64
#  4   Potential                 16122 non-null  int64
#  5   Club                      15926 non-null  object
#  6   Value                     16122 non-null  float64
#  7   Wage                      16122 non-null  object
#  8   Special                   16122 non-null  int64
#  9   Preferred Foot            16122 non-null  object
#  10  International Reputation  16122 non-null  float64
#  11  Weak Foot                 16122 non-null  float64
#  12  Skill Moves               16122 non-null  float64
# ...

# %%
#another columns that needs to change are Wage and Release Clause
df_outfield[['Wage','Release Clause']].head()
# Out:
#     Wage Release Clause
# 0  €565K        €226.5M
# 1  €405K        €127.1M
# 2  €290K        €228.1M
# 3  €355K        €196.4M
# 4  €340K        €172.1M

# %%
'''
since both Wage and Release Clause column are in the same format, we can use 
the previous function
'''
df_outfield['Wage'] = df_outfield['Wage'].apply(lambda x : EuroConvert(x))
df_outfield['Release Clause'].fillna("None", inplace = True)
df_outfield['Release Clause'] = df_outfield['Release Clause'].apply(lambda x : EuroConvert(x))

# %%
df_outfield[['Value','Wage','Release Clause']].head()
# Out:
#          Value      Wage  Release Clause
# 0  110500000.0  565000.0     226500000.0
# 1   77000000.0  405000.0     127100000.0
# 2  118500000.0  290000.0     228100000.0
# 3  102000000.0  355000.0     196400000.0
# 4   93000000.0  340000.0     172100000.0

# %%
df_outfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 76 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16122 non-null  object
#  1   Age                       16122 non-null  int64
#  2   Nationality               16122 non-null  object
#  3   Overall                   16122 non-null  int64
#  4   Potential                 16122 non-null  int64
#  5   Club                      15926 non-null  object
#  6   Value                     16122 non-null  float64
#  7   Wage                      16122 non-null  float64
#  8   Special                   16122 non-null  int64
#  9   Preferred Foot            16122 non-null  object
#  10  International Reputation  16122 non-null  float64
#  11  Weak Foot                 16122 non-null  float64
#  12  Skill Moves               16122 non-null  float64
# ...

# %%
#for club column, let's see what is going on
df_outfield[df_outfield['Club'].isna()]
# Out:
#                  Name  Age  ... SlidingTackle  Release Clause
# 399        L. Paredes   24  ...          72.0             0.0
# 476      A. Granqvist   33  ...          79.0             0.0
# 601      I. Smolnikov   29  ...          80.0             0.0
# 775         A. Dzyuba   29  ...          19.0             0.0
# 849         Luís Neto   30  ...          78.0             0.0
# ...               ...  ...  ...           ...             ...
# 15000        M. Smith   18  ...          52.0             0.0
# 15101  J. Lalrinzuala   19  ...          53.0             0.0
# 15157    A. Kuruniyan   21  ...          12.0             0.0
# 15185   G. Kostadinov   27  ...          67.0             0.0
# 15344        K. Taimi   26  ...          64.0             0.0
#
# [196 rows x 76 columns]

# %%
'''by the look of things, these players doesn't have any club, so we'll fill it 
string "No Club"'''

df_outfield['Club'].fillna("No Club", inplace = True)
df_outfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 76 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16122 non-null  object
#  1   Age                       16122 non-null  int64
#  2   Nationality               16122 non-null  object
#  3   Overall                   16122 non-null  int64
#  4   Potential                 16122 non-null  int64
#  5   Club                      16122 non-null  object
#  6   Value                     16122 non-null  float64
#  7   Wage                      16122 non-null  float64
#  8   Special                   16122 non-null  int64
#  9   Preferred Foot            16122 non-null  object
#  10  International Reputation  16122 non-null  float64
#  11  Weak Foot                 16122 non-null  float64
#  12  Skill Moves               16122 non-null  float64
# ...

# %%
df_outfield.head()
# Out:
#                 Name  Age  ... SlidingTackle  Release Clause
# 0           L. Messi   31  ...          26.0     226500000.0
# 1  Cristiano Ronaldo   33  ...          23.0     127100000.0
# 2          Neymar Jr   26  ...          33.0     228100000.0
# 3       K. De Bruyne   27  ...          51.0     196400000.0
# 4          E. Hazard   27  ...          22.0     172100000.0
#
# [5 rows x 76 columns]

# %%
#now let's see the values in other column and check what we can fix or process

col = ['Preferred Foot','Work Rate','Body Type']
for i in col:
 print("Column",i,":\n",df_outfield[i].value_counts(),'\n')

'''
looks like we need to change some values in Body Type column and differentiate
the Work Rate column
'''
# Out:
# Column Preferred Foot :
#  Right    12119
# Left      4003
# Name: Preferred Foot, dtype: int64
#
# Column Work Rate :
#  Medium/ Medium    7779
# High/ Medium      3170
# Medium/ High      1690
# High/ High        1015
# Medium/ Low        849
# High/ Low          697
# Low/ Medium        449
# Low/ High          439
# Low/ Low            34
# Name: Work Rate, dtype: int64
#
# Column Body Type :
#  Normal                 9143
# Lean                   5969
# Stocky                 1004
# PLAYER_BODY_TYPE_25       1
# Shaqiri                   1
# Neymar                    1
# Messi                     1
# C. Ronaldo                1
# Akinfenwa                 1
# Name: Body Type, dtype: int64
# '\nlooks like we need to change some values in Body Type column and differentiate\nthe Work Rate column\n'

# %%
'''
now we'll differentiate the workd rate column, left side means attacking work 
rate while right side shows defensive work rate
'''
df_outfield['Work Rate'].head()
# Out:
# 0    Medium/ Medium
# 1         High/ Low
# 2      High/ Medium
# 3        High/ High
# 4      High/ Medium
# Name: Work Rate, dtype: object

# %%
df_outfield['Attacking Work Rate'] = df_outfield['Work Rate'].str.split('/', expand = True)[0]
df_outfield['Defensive Work Rate'] = df_outfield['Work Rate'].str.split('/', expand = True)[1]
df_outfield[['Work Rate','Attacking Work Rate','Defensive Work Rate']].tail()
# Out:
#             Work Rate Attacking Work Rate Defensive Work Rate
# 16117  Medium/ Medium              Medium              Medium
# 16118  Medium/ Medium              Medium              Medium
# 16119  Medium/ Medium              Medium              Medium
# 16120  Medium/ Medium              Medium              Medium
# 16121  Medium/ Medium              Medium              Medium

# %%
'''
now that these values have been changed, some columns will be drop and for Body
Type column, upon further search, i can't seem to find what some of the players
body type is, so i'll just drop them
'''
df_outfield.drop(columns = ['Special','Work Rate','Joined','Body Type'], inplace = True)
df_outfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 74 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16122 non-null  object
#  1   Age                       16122 non-null  int64
#  2   Nationality               16122 non-null  object
#  3   Overall                   16122 non-null  int64
#  4   Potential                 16122 non-null  int64
#  5   Club                      16122 non-null  object
#  6   Value                     16122 non-null  float64
#  7   Wage                      16122 non-null  float64
#  8   Preferred Foot            16122 non-null  object
#  9   International Reputation  16122 non-null  float64
#  10  Weak Foot                 16122 non-null  float64
#  11  Skill Moves               16122 non-null  float64
#  12  Position                  16122 non-null  object
# ...

# %%
'''
finally, let's change the positions rating to integer, note : the '+' sign is 
present since from the start of the game, the players overtime the players improve
in this dataset, we'll use the ratings overtime
'''
df_outfield[['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM',
       'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM',
       'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']].head()
# Out:
#      LS    ST    RS    LW    LF    CF  ...   RWB    LB   LCB    CB   RCB    RB
# 0  88+2  88+2  88+2  92+2  93+2  93+2  ...  64+2  59+2  47+2  47+2  47+2  59+2
# 1  91+3  91+3  91+3  89+3  90+3  90+3  ...  65+3  61+3  53+3  53+3  53+3  61+3
# 2  84+3  84+3  84+3  89+3  89+3  89+3  ...  65+3  60+3  47+3  47+3  47+3  60+3
# 3  82+3  82+3  82+3  87+3  87+3  87+3  ...  77+3  73+3  66+3  66+3  66+3  73+3
# 4  83+3  83+3  83+3  89+3  88+3  88+3  ...  66+3  60+3  49+3  49+3  49+3  60+3
#
# [5 rows x 26 columns]

# %%
def RatingOvertime (x): 
  Rt = x.split('+')
  return int(Rt[0]) + int(Rt[1])

iterate = ['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM',
       'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM',
       'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']
for i in iterate : 
  df_outfield[i] = df_outfield[i].apply(lambda x : RatingOvertime(x))

df_outfield[iterate].head()
# Out:
#    LS  ST  RS  LW  LF  CF  RF  RW  ...  CDM  RDM  RWB  LB  LCB  CB  RCB  RB
# 0  90  90  90  94  95  95  95  94  ...   63   63   66  61   49  49   49  61
# 1  94  94  94  92  93  93  93  92  ...   64   64   68  64   56  56   56  64
# 2  87  87  87  92  92  92  92  92  ...   63   63   68  63   50  50   50  63
# 3  85  85  85  90  90  90  90  90  ...   80   80   80  76   69  69   69  76
# 4  86  86  86  92  91  91  91  92  ...   66   66   69  63   52  52   52  63
#
# [5 rows x 26 columns]

# %%
df_outfield.head()
# Out:
#                 Name  Age  ... Attacking Work Rate  Defensive Work Rate
# 0           L. Messi   31  ...              Medium               Medium
# 1  Cristiano Ronaldo   33  ...                High                  Low
# 2          Neymar Jr   26  ...                High               Medium
# 3       K. De Bruyne   27  ...                High                 High
# 4          E. Hazard   27  ...                High               Medium
#
# [5 rows x 74 columns]

# %%
df_outfield.info()
#now that this outfield_df has already have the right datatype and no null values,
#we'll now do some preprocessing on the GK df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 74 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16122 non-null  object
#  1   Age                       16122 non-null  int64
#  2   Nationality               16122 non-null  object
#  3   Overall                   16122 non-null  int64
#  4   Potential                 16122 non-null  int64
#  5   Club                      16122 non-null  object
#  6   Value                     16122 non-null  float64
#  7   Wage                      16122 non-null  float64
#  8   Preferred Foot            16122 non-null  object
#  9   International Reputation  16122 non-null  float64
#  10  Weak Foot                 16122 non-null  float64
#  11  Skill Moves               16122 non-null  float64
#  12  Position                  16122 non-null  object
# ...

# %% [markdown]
# ## Preprocessing on GK DF

# %%
df_GK.head()
# Out:
#     Unnamed: 0           Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 3            3         De Gea   27  ...          88.0        94.0         €138.6M
# 9            9       J. Oblak   25  ...          88.0        89.0         €144.5M
# 18          18  M. ter Stegen   26  ...          85.0        90.0         €123.3M
# 19          19    T. Courtois   26  ...          86.0        88.0         €113.7M
# 22          22       M. Neuer   32  ...          87.0        87.0          €62.7M
#
# [5 rows x 83 columns]

# %%
df_GK.info()
df_GK.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2025 entries, 3 to 18198
# Data columns (total 83 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2025 non-null   int64
#  1   Name                      2025 non-null   object
#  2   Age                       2025 non-null   int64
#  3   Nationality               2025 non-null   object
#  4   Overall                   2025 non-null   int64
#  5   Potential                 2025 non-null   int64
#  6   Club                      1992 non-null   object
#  7   Value                     2025 non-null   object
#  8   Wage                      2025 non-null   object
#  9   Special                   2025 non-null   int64
#  10  Preferred Foot            2025 non-null   object
#  11  International Reputation  2025 non-null   float64
#  12  Weak Foot                 2025 non-null   float64
# ...

# %%
#let's start by dropping columns that we don't need and resetting the index in this df
df_GK.reset_index(drop=True, inplace = True)
df_GK.drop(columns = ['Unnamed: 0', 'Special', 'Joined', 'Loaned From',
                      'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
                      'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
                      'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
                      ], inplace = True)
df_GK.head()
# Out:
#             Name  Age Nationality  ...  GKPositioning  GKReflexes Release Clause
# 0         De Gea   27       Spain  ...           88.0        94.0        €138.6M
# 1       J. Oblak   25    Slovenia  ...           88.0        89.0        €144.5M
# 2  M. ter Stegen   26     Germany  ...           85.0        90.0        €123.3M
# 3    T. Courtois   26     Belgium  ...           86.0        88.0        €113.7M
# 4       M. Neuer   32     Germany  ...           87.0        87.0         €62.7M
#
# [5 rows x 52 columns]

# %%
df_GK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2025 entries, 0 to 2024
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      2025 non-null   object
#  1   Age                       2025 non-null   int64
#  2   Nationality               2025 non-null   object
#  3   Overall                   2025 non-null   int64
#  4   Potential                 2025 non-null   int64
#  5   Club                      1992 non-null   object
#  6   Value                     2025 non-null   object
#  7   Wage                      2025 non-null   object
#  8   Preferred Foot            2025 non-null   object
#  9   International Reputation  2025 non-null   float64
#  10  Weak Foot                 2025 non-null   float64
#  11  Skill Moves               2025 non-null   float64
#  12  Work Rate                 2025 non-null   object
# ...

# %%
# now, same as the outfield DF, we will apply the same function to these columns
df_GK['Height'] = df_GK['Height'].apply(lambda x : ConvertHeight(x))

df_GK['Weight'] = df_GK['Weight'].str[:-3].astype(float)
df_GK['Weight'] = round(df_GK['Weight'] * 0.453592,2)

df_GK['Value'] = df_GK['Value'].apply(lambda x: EuroConvert(x))
df_GK['Wage'] = df_GK['Wage'].apply(lambda x : EuroConvert(x))
df_GK['Release Clause'].fillna("None", inplace = True)
df_GK['Release Clause'] = df_GK['Release Clause'].apply(lambda x : EuroConvert(x))

# %%
df_GK.head()
# Out:
#             Name  Age Nationality  ...  GKPositioning  GKReflexes Release Clause
# 0         De Gea   27       Spain  ...           88.0        94.0    138600000.0
# 1       J. Oblak   25    Slovenia  ...           88.0        89.0    144500000.0
# 2  M. ter Stegen   26     Germany  ...           85.0        90.0    123300000.0
# 3    T. Courtois   26     Belgium  ...           86.0        88.0    113700000.0
# 4       M. Neuer   32     Germany  ...           87.0        87.0     62700000.0
#
# [5 rows x 52 columns]

# %%
#check the total of missing values
df_GK.isnull().sum().sort_values(ascending = False)
# Out:
# Club                        33
# Release Clause               0
# Body Type                    0
# Curve                        0
# Dribbling                    0
# Volleys                      0
# ShortPassing                 0
# HeadingAccuracy              0
# Finishing                    0
# Weight                       0
# Height                       0
# Jersey Number                0
# Position                     0
# Work Rate                    0
# GKReflexes                   0
# Skill Moves                  0
# Weak Foot                    0
# International Reputation     0
# Preferred Foot               0
# Wage                         0
# Value                        0
# Potential                    0
# Overall                      0
# Nationality                  0
# Age                          0
# FKAccuracy                   0
# LongPassing                  0
# BallControl                  0
# Positioning                  0
# GKPositioning                0
# ...

# %%
df_GK[df_GK['Club'].isna()]
# Out:
#                  Name  Age  ... GKReflexes  Release Clause
# 68           A. Lunev   26  ...       85.0             0.0
# 119         J. Villar   41  ...       77.0             0.0
# 259       M. Banguera   32  ...       77.0             0.0
# 277         M. Borjan   30  ...       72.0             0.0
# 331       A. Silbeira   22  ...       72.0             0.0
# 340         D. Dibusz   27  ...       74.0             0.0
# 426          E. Conde   35  ...       70.0             0.0
# 445           D. Keet   28  ...       71.0             0.0
# 493       J. Silbeira   22  ...       72.0             0.0
# 514        B. Sangaré   32  ...       68.0             0.0
# 516    H. Halldórsson   34  ...       71.0             0.0
# 529         C. Cáceda   26  ...       72.0             0.0
# 532           R. Romo   28  ...       73.0             0.0
# 576         S. Ekramy   34  ...       79.0             0.0
# 594       A. Kovácsik   27  ...       75.0             0.0
# ...

# %%
# now, we'll fill the missing values and change some of the data
df_GK['Club'].fillna("No Club",inplace = True)

df_GK['Attacking Work Rate'] = df_GK['Work Rate'].str.split('/', expand = True)[0]
df_GK['Defensive Work Rate'] = df_GK['Work Rate'].str.split('/', expand = True)[1]
df_GK.drop(columns=['Work Rate'], inplace = True)

# %%
#lets check the unique values in body type column
df_GK['Body Type'].value_counts()
# Out:
# Normal      1445
# Lean         443
# Stocky       136
# Courtois       1
# Name: Body Type, dtype: int64

# %%
#so looks like that the column only have 1 different body type, however i decided to drop it anyway
# since after googling, can't seem to find what courtois body type is
df_GK.drop(columns=['Body Type'], inplace = True)

# %%
df_GK.head()
# Out:
#             Name  Age  ... Attacking Work Rate  Defensive Work Rate
# 0         De Gea   27  ...              Medium               Medium
# 1       J. Oblak   25  ...              Medium               Medium
# 2  M. ter Stegen   26  ...              Medium               Medium
# 3    T. Courtois   26  ...              Medium               Medium
# 4       M. Neuer   32  ...              Medium               Medium
#
# [5 rows x 52 columns]

# %%
df_GK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2025 entries, 0 to 2024
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      2025 non-null   object
#  1   Age                       2025 non-null   int64
#  2   Nationality               2025 non-null   object
#  3   Overall                   2025 non-null   int64
#  4   Potential                 2025 non-null   int64
#  5   Club                      2025 non-null   object
#  6   Value                     2025 non-null   float64
#  7   Wage                      2025 non-null   float64
#  8   Preferred Foot            2025 non-null   object
#  9   International Reputation  2025 non-null   float64
#  10  Weak Foot                 2025 non-null   float64
#  11  Skill Moves               2025 non-null   float64
#  12  Position                  2025 non-null   object
# ...
